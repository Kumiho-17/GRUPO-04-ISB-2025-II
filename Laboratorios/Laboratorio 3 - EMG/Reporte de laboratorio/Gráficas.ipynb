# %% [markdown]
# A continuación se detallan las gráficas para cada toma obtenida en sus respectivas posiciones.

# %%
import numpy as np
import matplotlib.pyplot as plt
emg = np.loadtxt(r"C:\Users\RODRIGO\Desktop\GRUPO-04-ISB-2025-II\Laboratorios\Laboratorio 3 - EMG\Registro de datos\Posición 1\Toma1_Reposo_Posición 1.txt")
señal = emg

fs = 1000
inicio = 49000
fin = 60000  # Use the number of rows
tiempo = np.arange(inicio, fin) / fs
plt.figure(figsize=(15, 5))
plt.plot(tiempo, señal[inicio:fin, 5])
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud (mV)')
plt.title('Grabación en reposo 1 para la posición 1')
plt.show()

# %%
emg = np.loadtxt(r"C:\Users\RODRIGO\Desktop\GRUPO-04-ISB-2025-II\Laboratorios\Laboratorio 3 - EMG\Registro de datos\Posición 1\Toma2_Reposo_Posición 1.txt")
señal = emg

fs = 1000
inicio = 1
fin = 10000  # Use the number of rows
tiempo = np.arange(inicio, fin) / fs
plt.figure(figsize=(15, 5))
plt.plot(tiempo, señal[inicio:fin, 5])
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud (mV)')
plt.title('Grabación en reposo 2 para la posición 1')
plt.show()

# %%
emg = np.loadtxt(r"C:\Users\RODRIGO\Desktop\GRUPO-04-ISB-2025-II\Laboratorios\Laboratorio 3 - EMG\Registro de datos\Posición 1\Toma1_Movimiento libre_Posición1.txt")
señal = emg

fs = 1000
inicio = 7000
fin = 20000  # Use the number of rows
tiempo = np.arange(inicio, fin) / fs
plt.figure(figsize=(15, 5))
plt.plot(tiempo, señal[inicio:fin, 5])
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud (mV)')
plt.title('Grabación en movimiento libre 1 para la posición 1')
plt.show()

# %%
emg = np.loadtxt(r"C:\Users\RODRIGO\Desktop\GRUPO-04-ISB-2025-II\Laboratorios\Laboratorio 3 - EMG\Registro de datos\Posición 1\Toma2_Movimiento libre_Posición1.txt")
señal = emg

fs = 1000
inicio = 10000
fin = 22000  # Use the number of rows
tiempo = np.arange(inicio, fin) / fs
plt.figure(figsize=(15, 5))
plt.plot(tiempo, señal[inicio:fin, 5])
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud (mV)')
plt.title('Grabación en movimiento libre 2 para la posición 1')
plt.show()

# %%
emg = np.loadtxt(r"C:\Users\RODRIGO\Desktop\GRUPO-04-ISB-2025-II\Laboratorios\Laboratorio 3 - EMG\Registro de datos\Posición 1\Toma3_Movimiento libre_Posición1.txt")
señal = emg

fs = 1000
inicio = 5000
fin = 17000  # Use the number of rows
tiempo = np.arange(inicio, fin) / fs
plt.figure(figsize=(15, 5))
plt.plot(tiempo, señal[inicio:fin, 5])
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud (mV)')
plt.title('Grabación en movimiento libre 3 para la posición 1')
plt.show()

# %%
emg = np.loadtxt(r"C:\Users\RODRIGO\Desktop\GRUPO-04-ISB-2025-II\Laboratorios\Laboratorio 3 - EMG\Registro de datos\Posición 1\Toma1_Movimiento en contra_Posición1.txt")
señal = emg

fs = 1000
inicio = 4000
fin = 15000  # Use the number of rows
tiempo = np.arange(inicio, fin) / fs
plt.figure(figsize=(15, 5))
plt.plot(tiempo, señal[inicio:fin, 5])
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud (mV)')
plt.title('Grabación en movimiento en contra 1 para la posición 1')
plt.show()

# %%
emg = np.loadtxt(r"C:\Users\RODRIGO\Desktop\GRUPO-04-ISB-2025-II\Laboratorios\Laboratorio 3 - EMG\Registro de datos\Posición 1\Toma2_Movimiento en contra_Posición1.txt")
señal = emg

fs = 1000
inicio = 4000
fin = 14000  # Use the number of rows
tiempo = np.arange(inicio, fin) / fs
plt.figure(figsize=(15, 5))
plt.plot(tiempo, señal[inicio:fin, 5])
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud (mV)')
plt.title('Grabación en movimiento en contra 2 para la posición 1')
plt.show()

# %%
emg = np.loadtxt(r"C:\Users\RODRIGO\Desktop\GRUPO-04-ISB-2025-II\Laboratorios\Laboratorio 3 - EMG\Registro de datos\Posición 1\Toma3_Movimiento en contra_Posición1.txt")
señal = emg

fs = 1000
inicio = 7500
fin = 18000  # Use the number of rows
tiempo = np.arange(inicio, fin) / fs
plt.figure(figsize=(15, 5))
plt.plot(tiempo, señal[inicio:fin, 5])
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud (mV)')
plt.title('Grabación en movimiento en contra 3 para la posición 1')
plt.show()

# %%
emg = np.loadtxt(r"C:\Users\RODRIGO\Desktop\GRUPO-04-ISB-2025-II\Laboratorios\Laboratorio 3 - EMG\Registro de datos\Posición 2\Toma1_Reposo_Posición2.txt")
señal = emg

fs = 1000
inicio = 1
fin = 20000  # Use the number of rows
tiempo = np.arange(inicio, fin) / fs
plt.figure(figsize=(15, 5))
plt.plot(tiempo, señal[inicio:fin, 5])
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud (mV)')
plt.title('Grabación en Reposo 1 para la posición 2')
plt.show()

# %%
emg = np.loadtxt(r"C:\Users\RODRIGO\Desktop\GRUPO-04-ISB-2025-II\Laboratorios\Laboratorio 3 - EMG\Registro de datos\Posición 2\Toma2_Reposo_Posición2.txt")
señal = emg

fs = 1000
inicio = 1
fin = 10000  # Use the number of rows
tiempo = np.arange(inicio, fin) / fs
plt.figure(figsize=(15, 5))
plt.plot(tiempo, señal[inicio:fin, 5])
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud (mV)')
plt.title('Grabación en Reposo 2 para la posición 2')
plt.show()

# %%
emg = np.loadtxt(r"C:\Users\RODRIGO\Desktop\GRUPO-04-ISB-2025-II\Laboratorios\Laboratorio 3 - EMG\Registro de datos\Posición 2\Toma1_Movimiento libre_Posición2.txt")
señal = emg

fs = 1000
inicio = 1
fin = 10000  # Use the number of rows
tiempo = np.arange(inicio, fin) / fs
plt.figure(figsize=(15, 5))
plt.plot(tiempo, señal[inicio:fin, 5])
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud (mV)')
plt.title('Grabación en movimiento libre 1 para la posición 2')
plt.show()

# %%
emg = np.loadtxt(r"C:\Users\RODRIGO\Desktop\GRUPO-04-ISB-2025-II\Laboratorios\Laboratorio 3 - EMG\Registro de datos\Posición 2\Toma2_Movimiento libre_Posición2.txt")
señal = emg

fs = 1000
inicio = 1
fin = 10000  # Use the number of rows
tiempo = np.arange(inicio, fin) / fs
plt.figure(figsize=(15, 5))
plt.plot(tiempo, señal[inicio:fin, 5])
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud (mV)')
plt.title('Grabación en movimiento libre 2 para la posición 2')
plt.show()

# %%
emg = np.loadtxt(r"C:\Users\RODRIGO\Desktop\GRUPO-04-ISB-2025-II\Laboratorios\Laboratorio 3 - EMG\Registro de datos\Posición 2\Toma3_Movimiento libre_Posición2.txt")
señal = emg

fs = 1000
inicio = 1
fin = 10000  # Use the number of rows
tiempo = np.arange(inicio, fin) / fs
plt.figure(figsize=(15, 5))
plt.plot(tiempo, señal[inicio:fin, 5])
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud (mV)')
plt.title('Grabación en movimiento libre 3 para la posición 2')
plt.show()

# %%
emg = np.loadtxt(r"C:\Users\RODRIGO\Desktop\GRUPO-04-ISB-2025-II\Laboratorios\Laboratorio 3 - EMG\Registro de datos\Posición 2\Toma1_Movimiento en contra_Posición2.txt")
señal = emg

fs = 1000
inicio = 1
fin = 10000  # Use the number of rows
tiempo = np.arange(inicio, fin) / fs
plt.figure(figsize=(15, 5))
plt.plot(tiempo, señal[inicio:fin, 5])
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud (mV)')
plt.title('Grabación en movimiento en contra 1 para la posición 2')
plt.show()

# %%
emg = np.loadtxt(r"C:\Users\RODRIGO\Desktop\GRUPO-04-ISB-2025-II\Laboratorios\Laboratorio 3 - EMG\Registro de datos\Posición 2\Toma2_Movimiento en contra_Posición2.txt")
señal = emg

fs = 1000
inicio = 1
fin = 10000  # Use the number of rows
tiempo = np.arange(inicio, fin) / fs
plt.figure(figsize=(15, 5))
plt.plot(tiempo, señal[inicio:fin, 5])
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud (mV)')
plt.title('Grabación en movimiento en contra 2 para la posición 2')
plt.show()

# %%
emg = np.loadtxt(r"C:\Users\RODRIGO\Desktop\GRUPO-04-ISB-2025-II\Laboratorios\Laboratorio 3 - EMG\Registro de datos\Posición 2\Toma3_Movimiento en contra_Posición2.txt")
señal = emg

fs = 1000
inicio = 1
fin = 10000  # Use the number of rows
tiempo = np.arange(inicio, fin) / fs
plt.figure(figsize=(15, 5))
plt.plot(tiempo, señal[inicio:fin, 5])
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud (mV)')
plt.title('Grabación en movimiento en contra 3 para la posición 2')
plt.show()

# %%
emg = np.loadtxt(r"C:\Users\RODRIGO\Desktop\GRUPO-04-ISB-2025-II\Laboratorios\Laboratorio 3 - EMG\Registro de datos\Posición 3\Toma1_Reposo_Posición3.txt")
señal = emg

fs = 1000
inicio = 1
fin = 10000  # Use the number of rows
tiempo = np.arange(inicio, fin) / fs
plt.figure(figsize=(15, 5))
plt.plot(tiempo, señal[inicio:fin, 5])
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud (mV)')
plt.title('Grabación en reposo 1 para la posición 3')
plt.show()

# %%
emg = np.loadtxt(r"C:\Users\RODRIGO\Desktop\GRUPO-04-ISB-2025-II\Laboratorios\Laboratorio 3 - EMG\Registro de datos\Posición 3\Toma2_Reposo_Posición3.txt")
señal = emg

fs = 1000
inicio = 1
fin = 8000  # Use the number of rows
tiempo = np.arange(inicio, fin) / fs
plt.figure(figsize=(15, 5))
plt.plot(tiempo, señal[inicio:fin, 5])
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud (mV)')
plt.title('Grabación en reposo 2 para la posición 3')
plt.show()

# %%
emg = np.loadtxt(r"C:\Users\RODRIGO\Desktop\GRUPO-04-ISB-2025-II\Laboratorios\Laboratorio 3 - EMG\Registro de datos\Posición 3\Toma1_Movimiento libre_Posición3.txt")
señal = emg

fs = 1000
inicio = 1
fin = 10000  # Use the number of rows
tiempo = np.arange(inicio, fin) / fs
plt.figure(figsize=(15, 5))
plt.plot(tiempo, señal[inicio:fin, 5])
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud (mV)')
plt.title('Grabación en movimiento libre 1 para la posición 3')
plt.show()

# %%
emg = np.loadtxt(r"C:\Users\RODRIGO\Desktop\GRUPO-04-ISB-2025-II\Laboratorios\Laboratorio 3 - EMG\Registro de datos\Posición 3\Toma2_Movimiento libre_Posición3.txt")
señal = emg

fs = 1000
inicio = 1
fin = 10000  # Use the number of rows
tiempo = np.arange(inicio, fin) / fs
plt.figure(figsize=(15, 5))
plt.plot(tiempo, señal[inicio:fin, 5])
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud (mV)')
plt.title('Grabación en movimiento libre 2 para la posición 3')
plt.show()

# %%
emg = np.loadtxt(r"C:\Users\RODRIGO\Desktop\GRUPO-04-ISB-2025-II\Laboratorios\Laboratorio 3 - EMG\Registro de datos\Posición 3\Toma3_Movimiento libre_Posición3.txt")
señal = emg

fs = 1000
inicio = 1
fin = 10000  # Use the number of rows
tiempo = np.arange(inicio, fin) / fs
plt.figure(figsize=(15, 5))
plt.plot(tiempo, señal[inicio:fin, 5])
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud (mV)')
plt.title('Grabación en movimiento libre 3 para la posición 3')
plt.show()

# %%
emg = np.loadtxt(r"C:\Users\RODRIGO\Desktop\GRUPO-04-ISB-2025-II\Laboratorios\Laboratorio 3 - EMG\Registro de datos\Posición 3\Toma1_Movimiento en contra_Posición3.txt")
señal = emg

fs = 1000
inicio = 1
fin = 10000  # Use the number of rows
tiempo = np.arange(inicio, fin) / fs
plt.figure(figsize=(15, 5))
plt.plot(tiempo, señal[inicio:fin, 5])
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud (mV)')
plt.title('Grabación en movimiento en contra 1 para la posición 3')
plt.show()

# %%
emg = np.loadtxt(r"C:\Users\RODRIGO\Desktop\GRUPO-04-ISB-2025-II\Laboratorios\Laboratorio 3 - EMG\Registro de datos\Posición 3\Toma2_Movimiento en contra_Posición3.txt")
señal = emg

fs = 1000
inicio = 1
fin = 10000  # Use the number of rows
tiempo = np.arange(inicio, fin) / fs
plt.figure(figsize=(15, 5))
plt.plot(tiempo, señal[inicio:fin, 5])
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud (mV)')
plt.title('Grabación en movimiento en contra 2 para la posición 3')
plt.show()

# %%
emg = np.loadtxt(r"C:\Users\RODRIGO\Desktop\GRUPO-04-ISB-2025-II\Laboratorios\Laboratorio 3 - EMG\Registro de datos\Posición 3\Toma3_Movimiento en contra_Posición3.txt")
señal = emg

fs = 1000
inicio = 1
fin = 7000  # Use the number of rows
tiempo = np.arange(inicio, fin) / fs
plt.figure(figsize=(15, 5))
plt.plot(tiempo, señal[inicio:fin, 5])
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud (mV)')
plt.title('Grabación en movimiento en contra 3 para la posición 3')
plt.show()
